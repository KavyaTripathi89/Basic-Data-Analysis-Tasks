# %%
import pandas as pd

# %%
data_csv = pd.read_csv(r"C:\Users\kavya\Downloads\DataAnalysis Project\project tasks_data_mito.csv")

# %%
data_csv
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year
# ...

# %% [markdown]
# # Adding a new column at last

# %%
data_csv['new_quantity'] = data_csv['quantity'] * 10

# %%
data_csv
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# # Adding a new column at a particular place

# %%
data_csv.insert(10, 'NewSales',data_csv['sales']*10 )

# %%
data_csv
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# # Delete a column

# %%
data_csv.drop('NewSales', axis=1, inplace=True)

# %%
data_csv.drop('new_sales', axis=1, inplace=True)

# %%
data_csv
# Out:
#               order_id  order_date     customer_name      segment  \
# 0         AG-2011-2040  01-01-2011   Toby Braunhardt     Consumer
# 1        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# 2         HU-2011-1220  01-01-2011     Annie Thurman     Consumer
# 3      IT-2011-3647632  01-01-2011      Eugene Moren  Home Office
# 4        IN-2011-47883  01-01-2011       Joseph Holt     Consumer
# ...                ...         ...               ...          ...
# 51285   CA-2014-115427  12/31/2014        Erica Bern    Corporate
# 51286     MO-2014-2560  12/31/2014         Liz Preis     Consumer
# 51287   MX-2014-110527  12/31/2014  Charlotte Melton     Consumer
# 51288   MX-2014-114783  12/31/2014     Tamara Dahlen     Consumer
# 51289   CA-2014-156720  12/31/2014     Jill Matthias     Consumer
#
#              country   region        product_id         category  \
# 0            Algeria   Africa  OFF-TEN-10000025  Office Supplies
# ...

# %% [markdown]
# # Sorting a Dataframe

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %%
data_csv.sort_values(by='profit', ascending=False)
# Out:
#              order_id  order_date   customer_name      segment        country  \
# 29530  CA-2013-118689  10-03-2013    Tamara Chand    Corporate  United States
# 36239  CA-2014-140151   3/24/2014    Raymond Buch     Consumer  United States
# 48097  CA-2014-166709  11/18/2014    Hunter Lopez     Consumer  United States
# 33011  CA-2013-117121  12/18/2013   Adrian Barton     Consumer  United States
# 5522   CA-2011-116904   9/23/2011    Sanjit Chand     Consumer  United States
# ...               ...         ...             ...          ...            ...
# 37130  CA-2014-134845   4/18/2014  Sharelle Roach  Home Office  United States
# 3775   CA-2011-169019   7/26/2011     Luke Foster     Consumer  United States
# 47195  US-2014-168116  11-05-2014  Grant Thornton    Corporate  United States
# 29212    TU-2013-9400   9/26/2013   Denise Monton    Corporate         Turkey
# 31884  CA-2013-108196  11/26/2013   Cindy Stewart     Consumer  United States
#
# ...

# %% [markdown]
# # Filter Dataframe

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %%
data_csv[data_csv['region'] == 'Africa']
# Out:
#            order_id  order_date       customer_name      segment      country  \
# 0      AG-2011-2040  01-01-2011     Toby Braunhardt     Consumer      Algeria
# 23     TZ-2011-7370  01-03-2011          Jack Garza     Consumer     Tanzania
# 41     SU-2011-5190  01-04-2011     Jasper Cacioppo     Consumer        Sudan
# 42     SU-2011-5190  01-04-2011     Jasper Cacioppo     Consumer        Sudan
# 55     AO-2011-4910  01-06-2011         Grace Kelly    Corporate       Angola
# ...             ...         ...                 ...          ...          ...
# 51252  OD-2014-9490  12/31/2014    Mitch Willingham    Corporate  South Sudan
# 51253  AO-2014-7730  12/31/2014        Ken Lonsdale     Consumer       Angola
# 51262  TZ-2014-8350  12/31/2014        Joseph Airdo     Consumer     Tanzania
# 51280  TZ-2014-8220  12/31/2014  Christine Kargatis  Home Office     Tanzania
# 51286  MO-2014-2560  12/31/2014           Liz Preis     Consumer      Morocco
#
# ...

# %% [markdown]
# # Filter Dataframe - AND Operator

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %%
data_csv[(data_csv['segment'] == 'Corporate') & (data_csv['category'] == 'Technology')]
# Out:
#              order_id  order_date     customer_name    segment  \
# 28     MX-2011-140641  01-04-2011       Maya Herman  Corporate
# 32     MX-2011-140641  01-04-2011       Maya Herman  Corporate
# 55       AO-2011-4910  01-06-2011       Grace Kelly  Corporate
# 66       LE-2011-9590  01-07-2011       Harry Marie  Corporate
# 92      ID-2011-20814  01-09-2011        Ed Braxton  Corporate
# ...               ...         ...               ...        ...
# 51250   IN-2014-78228  12/31/2014       Maya Herman  Corporate
# 51251  MX-2014-122511  12/31/2014         Rick Reed  Corporate
# 51252    OD-2014-9490  12/31/2014  Mitch Willingham  Corporate
# 51259  MX-2014-116267  12/31/2014        Erica Bern  Corporate
# 51275   ID-2014-54442  12/31/2014   Muhammed Yedwab  Corporate
#
#                   country          region        product_id    category  \
# 28                 Mexico           North   TEC-AC-10001082  Technology
# ...

# %%
data_csv[(data_csv['country'] == 'Canada') | (data_csv['sales'] > '500')]
# Out:
#              order_id  order_date     customer_name    segment      country  \
# 2        HU-2011-1220  01-01-2011     Annie Thurman   Consumer      Hungary
# 5       IN-2011-47883  01-01-2011       Joseph Holt   Consumer    Australia
# 6        CA-2011-1510  01-02-2011   Magdelene Morse   Consumer       Canada
# 8       ID-2011-80230  01-03-2011      Ken Lonsdale   Consumer  New Zealand
# 9        IZ-2011-4680  01-03-2011  Lindsay Williams  Corporate         Iraq
# ...               ...         ...               ...        ...          ...
# 51270   IN-2014-23754  12/31/2014      Kalyca Meade  Corporate        China
# 51271   IN-2014-75603  12/31/2014      Bill Shonely  Corporate        India
# 51275   ID-2014-54442  12/31/2014   Muhammed Yedwab  Corporate  Philippines
# 51283   IN-2014-23754  12/31/2014      Kalyca Meade  Corporate        China
# 51288  MX-2014-114783  12/31/2014     Tamara Dahlen   Consumer       Mexico
#
# ...

# %% [markdown]
# # Pivot Table

# %%
data_csv.head()
# Out:
#           order_id  order_date    customer_name      segment    country  \
# 0     AG-2011-2040  01-01-2011  Toby Braunhardt     Consumer    Algeria
# 1    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
# 2     HU-2011-1220  01-01-2011    Annie Thurman     Consumer    Hungary
# 3  IT-2011-3647632  01-01-2011     Eugene Moren  Home Office     Sweden
# 4    IN-2011-47883  01-01-2011      Joseph Holt     Consumer  Australia
#
#     region        product_id         category                 product_name  \
# 0   Africa  OFF-TEN-10000025  Office Supplies          Tenex Lockers, Blue
# 1  Oceania   OFF-SU-10000618  Office Supplies     Acme Trimmer, High Speed
# 2     EMEA  OFF-TEN-10001585  Office Supplies      Tenex Box, Single Width
# 3    North   OFF-PA-10001492  Office Supplies  Enermax Note Cards, Premium
# 4  Oceania   FUR-FU-10003447        Furniture   Eldon Light Bulb, Duo Pack
#
#   sales  quantity  discount   profit  year  new_quantity
# ...

# %% [markdown]
# # Scatter Plot

# %%
data_csv.head(2)
# Out:
#         order_id  order_date    customer_name   segment    country   region  \
# 0   AG-2011-2040  01-01-2011  Toby Braunhardt  Consumer    Algeria   Africa
# 1  IN-2011-47883  01-01-2011      Joseph Holt  Consumer  Australia  Oceania
#
#          product_id         category              product_name sales  \
# 0  OFF-TEN-10000025  Office Supplies       Tenex Lockers, Blue   408
# 1   OFF-SU-10000618  Office Supplies  Acme Trimmer, High Speed   120
#
#    quantity  discount   profit  year  new_quantity
# 0         2       0.0  106.140  2011            20
# 1         3       0.1   36.036  2011            30

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(data_csv.sales, data_csv['profit'], color='g', s=40, edgecolor='y')
plt.xlabel('sales') , plt.ylabel('Profit')
plt.show()
